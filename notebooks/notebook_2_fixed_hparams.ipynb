# %% [markdown]
# # Notebook 2 — Fixed-Hyperparameter Rerun
#
# This notebook reruns selected paper points using the shipped fixed hyperparameters. Set `AEC_EXECUTE=1` before execution to start training; otherwise it produces a bounded execution plan.

# %% [markdown]
# ## Setup
#
# This cell checks the environment and creates portable output directories.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path.cwd().resolve()
while REPO_ROOT != REPO_ROOT.parent and not (REPO_ROOT / 'aec').is_dir():
    REPO_ROOT = REPO_ROOT.parent
sys.path.insert(0, str(REPO_ROOT))
from aec.environment import check_environment
from aec.paths import ensure_runtime_dirs
ensure_runtime_dirs()
ENV = check_environment(require_gpu=False)
print('Repository:', REPO_ROOT)
# Out:
# {'python': '3.10.20', 'executable': '/home/hzw/miniconda3/envs/HZWDP/bin/python', 'versions': {'torch': '2.5.1+cu121', 'torch-geometric': '2.7.0', 'numpy': '2.2.6', 'pandas': '2.3.3', 'matplotlib': '3.10.9', 'pyyaml': '6.0.3'}, 'cuda_available': True, 'cuda_count': 8, 'gpu_ids': [0], 'max_parallel_per_gpu': 1}
# Repository: /home/hzw/Rethinking_DP_GNN

# %% [markdown]
# ### Figure 1
# Plan or execute the fixed-hyperparameter rerun, then render the corresponding figure.

# %%
from aec.fixed_runner import run_fixed
from aec.figures import render_reference
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
repeats = int(os.environ.get('AEC_REPEATS', '3'))
jobs = run_fixed(1, repeats=repeats, execute=execute)
manifest = render_reference(1, mode='fixed')
print({'planned_or_run_jobs': len(jobs), 'render': manifest})
# Out:
# planned 756 fixed jobs for figure 1; execute=False
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure1_fixed/figure1.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure1_fixed/figure1.png
# {
#   "figure_id": 1,
#   "mode": "fixed",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure1_fixed",
#   "reference_table": "figure1_plot_data.csv"
# }
# {'planned_or_run_jobs': 756, 'render': {'figure_id': 1, 'mode': 'fixed', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure1_fixed', 'reference_table': 'figure1_plot_data.csv'}}

# %% [markdown]
# ### Figure 2
# Plan or execute the fixed-hyperparameter rerun, then render the corresponding figure.

# %%
from aec.fixed_runner import run_fixed
from aec.figures import render_reference
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
repeats = int(os.environ.get('AEC_REPEATS', '3'))
jobs = run_fixed(2, repeats=repeats, execute=execute)
manifest = render_reference(2, mode='fixed')
print({'planned_or_run_jobs': len(jobs), 'render': manifest})
# Out:
# planned 0 fixed jobs for figure 2; execute=False
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure2_fixed/cora_alpha_epsilon_m_panels.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure2_fixed/cora_alpha_epsilon_m_panels.png
# {
#   "figure_id": 2,
#   "mode": "fixed",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure2_fixed",
#   "reference_table": null
# }
# {'planned_or_run_jobs': 0, 'render': {'figure_id': 2, 'mode': 'fixed', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure2_fixed', 'reference_table': None}}

# %% [markdown]
# ### Figure 3
# Plan or execute the fixed-hyperparameter rerun, then render the corresponding figure.

# %%
from aec.fixed_runner import run_fixed
from aec.figures import render_reference
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
repeats = int(os.environ.get('AEC_REPEATS', '3'))
jobs = run_fixed(3, repeats=repeats, execute=execute)
manifest = render_reference(3, mode='fixed')
print({'planned_or_run_jobs': len(jobs), 'render': manifest})
# Out:
# planned 135 fixed jobs for figure 3; execute=False
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure3_fixed/figure4_final_ldp_sim_panels.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure3_fixed/figure4_final_ldp_sim_panels.png
# {
#   "figure_id": 3,
#   "mode": "fixed",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure3_fixed",
#   "reference_table": "figure3_plot_data.csv"
# }
# {'planned_or_run_jobs': 135, 'render': {'figure_id': 3, 'mode': 'fixed', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure3_fixed', 'reference_table': 'figure3_plot_data.csv'}}

# %% [markdown]
# ### Figure 4
# Plan or execute the fixed-hyperparameter rerun, then render the corresponding figure.

# %%
from aec.fixed_runner import run_fixed
from aec.figures import render_reference
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
repeats = int(os.environ.get('AEC_REPEATS', '3'))
jobs = run_fixed(4, repeats=repeats, execute=execute)
manifest = render_reference(4, mode='fixed')
print({'planned_or_run_jobs': len(jobs), 'render': manifest})
# Out:
# planned 363 fixed jobs for figure 4; execute=False
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure4_fixed/figure5_final_norm_scale_curves.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure4_fixed/figure5_final_norm_scale_curves.png
# {
#   "figure_id": 4,
#   "mode": "fixed",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure4_fixed",
#   "reference_table": "figure4_plot_data.csv"
# }
# {'planned_or_run_jobs': 363, 'render': {'figure_id': 4, 'mode': 'fixed', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure4_fixed', 'reference_table': 'figure4_plot_data.csv'}}

# %% [markdown]
# ### Figure 5
# Plan or execute the fixed-hyperparameter rerun, then render the corresponding figure.

# %%
from aec.fixed_runner import run_fixed
from aec.figures import render_reference
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
repeats = int(os.environ.get('AEC_REPEATS', '3'))
jobs = run_fixed(5, repeats=repeats, execute=execute)
manifest = render_reference(5, mode='fixed')
print({'planned_or_run_jobs': len(jobs), 'render': manifest})
# Out:
# planned 243 fixed jobs for figure 5; execute=False
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure5_fixed/figure6_tao2_curves.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure5_fixed/figure6_tao2_curves.png
# {
#   "figure_id": 5,
#   "mode": "fixed",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure5_fixed",
#   "reference_table": "figure5_plot_data.csv"
# }
# {'planned_or_run_jobs': 243, 'render': {'figure_id': 5, 'mode': 'fixed', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure5_fixed', 'reference_table': 'figure5_plot_data.csv'}}

# %% [markdown]
# ### Figure 6
# Plan or execute the fixed-hyperparameter rerun, then render the corresponding figure.

# %%
from aec.fixed_runner import run_fixed
from aec.figures import render_reference
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
repeats = int(os.environ.get('AEC_REPEATS', '3'))
jobs = run_fixed(6, repeats=repeats, execute=execute)
manifest = render_reference(6, mode='fixed')
print({'planned_or_run_jobs': len(jobs), 'render': manifest})
# Out:
# planned 252 fixed jobs for figure 6; execute=False
# {
#   "figure_id": 6,
#   "mode": "fixed",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure6_fixed",
#   "reference_table": "figure6_plot_data.csv"
# }
# {'planned_or_run_jobs': 252, 'render': {'figure_id': 6, 'mode': 'fixed', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure6_fixed', 'reference_table': 'figure6_plot_data.csv'}}

# %% [markdown]
# ### Figure 7
# Plan or execute the fixed-hyperparameter rerun, then render the corresponding figure.

# %%
from aec.fixed_runner import run_fixed
from aec.figures import render_reference
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
repeats = int(os.environ.get('AEC_REPEATS', '3'))
jobs = run_fixed(7, repeats=repeats, execute=execute)
manifest = render_reference(7, mode='fixed')
print({'planned_or_run_jobs': len(jobs), 'render': manifest})
# Out:
# planned 363 fixed jobs for figure 7; execute=False
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure7_fixed/figure5_heter.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure7_fixed/figure5_heter.png
# {
#   "figure_id": 7,
#   "mode": "fixed",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure7_fixed",
#   "reference_table": "figure7_plot_data.csv"
# }
# {'planned_or_run_jobs': 363, 'render': {'figure_id': 7, 'mode': 'fixed', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure7_fixed', 'reference_table': 'figure7_plot_data.csv'}}

# %% [markdown]
# ### Figure 8
# Plan or execute the fixed-hyperparameter rerun, then render the corresponding figure.

# %%
from aec.fixed_runner import run_fixed
from aec.figures import render_reference
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
repeats = int(os.environ.get('AEC_REPEATS', '3'))
jobs = run_fixed(8, repeats=repeats, execute=execute)
manifest = render_reference(8, mode='fixed')
print({'planned_or_run_jobs': len(jobs), 'render': manifest})
# Out:
# planned 0 fixed jobs for figure 8; execute=False
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure8_fixed/cora_pm_hds_alpha_lambda_epsilon.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure8_fixed/cora_pm_hds_alpha_lambda_epsilon.png
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure8_fixed/cora_pm_hds_alpha_lambda_epsilon_curve.csv
# Curve rows: 3211
# {
#   "figure_id": 8,
#   "mode": "fixed",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure8_fixed",
#   "reference_table": null
# }
# {'planned_or_run_jobs': 0, 'render': {'figure_id': 8, 'mode': 'fixed', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure8_fixed', 'reference_table': None}}

# %% [markdown]
# ## Table 4 and Table 6
#
# The tables are generated from the experiment implementation labels `FeatFree-P`, `FeatFree-Kprop`, and `FeatFree-HOA`.

# %%
from aec.fixed_runner import run_fixed_table
from aec.tables import render_table
execute = os.environ.get("AEC_EXECUTE", "0") == "1"
run_fixed_table("table4", repeats=int(os.environ.get("AEC_REPEATS", "3")), execute=execute)
render_table("table4", mode="fixed")
# Out:
# planned 12 table4 groups
# {
#   "table": "table4",
#   "mode": "fixed",
#   "rows": 12,
#   "seed_rows": 120
# }
# {'table': 'table4', 'mode': 'fixed', 'rows': 12, 'seed_rows': 120}

# %%
from aec.fixed_runner import run_fixed_table
from aec.tables import render_table
execute = os.environ.get("AEC_EXECUTE", "0") == "1"
run_fixed_table("table6", repeats=int(os.environ.get("AEC_REPEATS", "3")), execute=execute)
render_table("table6", mode="fixed")
# Out:
# planned 72 table6 groups
# {
#   "table": "table6",
#   "mode": "fixed",
#   "rows": 72,
#   "seed_rows": 720
# }
# {'table': 'table6', 'mode': 'fixed', 'rows': 72, 'seed_rows': 720}
