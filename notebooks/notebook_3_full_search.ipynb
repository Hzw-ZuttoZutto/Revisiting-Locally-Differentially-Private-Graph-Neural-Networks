# %% [markdown]
# # Notebook 3 — Search and Reproduce
#
# This notebook preserves the full AEC search path. It defaults to the claim-coverage scaled mode; use `AEC_MODE=full` with suitable compute for the complete configuration expansion.

# %% [markdown]
# ## Setup
#
# This cell checks the environment and creates portable output directories.

# %%
# Notebook configuration. Run this cell before the setup cell.
import os
AEC_EXECUTE = True  # Set True to run the search; False only prints the plan.
AEC_GPU_IDS = '0'  # Comma-separated GPU IDs, for example '0,1'.
AEC_MAX_PARALLEL_PER_GPU = 1
AEC_MODE = 'scaled'  # Use 'full' for the complete search.

if not AEC_GPU_IDS.strip(): raise ValueError('AEC_GPU_IDS cannot be empty')
if int(AEC_MAX_PARALLEL_PER_GPU) < 1: raise ValueError('AEC_MAX_PARALLEL_PER_GPU must be >= 1')
if AEC_MODE not in {"scaled", "full"}: raise ValueError("AEC_MODE must be scaled or full")

os.environ['AEC_EXECUTE'] = '1' if AEC_EXECUTE else '0'
os.environ['AEC_GPU_IDS'] = AEC_GPU_IDS
os.environ['AEC_MAX_PARALLEL_PER_GPU'] = str(AEC_MAX_PARALLEL_PER_GPU)
os.environ['AEC_MODE'] = AEC_MODE
print({'AEC_EXECUTE': os.environ['AEC_EXECUTE'], 'AEC_GPU_IDS': os.environ['AEC_GPU_IDS'], 'AEC_MAX_PARALLEL_PER_GPU': os.environ['AEC_MAX_PARALLEL_PER_GPU'], 'AEC_MODE': os.environ['AEC_MODE']})

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path.cwd().resolve()
while REPO_ROOT != REPO_ROOT.parent and not (REPO_ROOT / 'scripts' / 'aec').is_dir():
    REPO_ROOT = REPO_ROOT.parent
sys.path.insert(0, str(REPO_ROOT))
from scripts.aec.environment import check_environment
from scripts.aec.paths import ensure_runtime_dirs
ensure_runtime_dirs()
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
ENV = check_environment(require_gpu=execute)
print('Repository:', REPO_ROOT)

# %% [markdown]
# ### Dataset preflight
#
# Download/process all six datasets sequentially before Figure 1 starts.

# %%
from scripts.aec.data_preflight import ensure_datasets

dataset_preflight = ensure_datasets(REPO_ROOT)
print({'datasets_ready': dataset_preflight})

# %% [markdown]
# ### Figure 1
# Expand the selected search configuration and render the figure.

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(1, mode=mode, execute=execute)
if execute:
    manifest = render_reference(1, mode=f'search_{mode}')
    print({'search': search, 'render': manifest})

# %% [markdown]
# ### Figure 2
# Expand the selected search configuration and render the figure.

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(2, mode=mode, execute=execute)
if execute:
    manifest = render_reference(2, mode=f'search_{mode}')
    print({'search': search, 'render': manifest})

# %% [markdown]
# ### Figure 3
# Expand the selected search configuration and render the figure.

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(3, mode=mode, execute=execute)
if execute:
    manifest = render_reference(3, mode=f'search_{mode}')
    print({'search': search, 'render': manifest})

# %% [markdown]
# ### Figure 4
# Expand the selected search configuration and render the figure.

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(4, mode=mode, execute=execute)
if execute:
    manifest = render_reference(4, mode=f'search_{mode}')
    print({'search': search, 'render': manifest})

# %% [markdown]
# ### Figure 5
# Expand the selected search configuration and render the figure.

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(5, mode=mode, execute=execute)
if execute:
    manifest = render_reference(5, mode=f'search_{mode}')
    print({'search': search, 'render': manifest})

# %% [markdown]
# ### Figure 6
# Expand the selected search configuration and render the figure.

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(6, mode=mode, execute=execute)
if execute:
    manifest = render_reference(6, mode=f'search_{mode}')
    print({'search': search, 'render': manifest})

# %% [markdown]
# ### Figure 7
# Expand the selected search configuration and render the figure.

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(7, mode=mode, execute=execute)
if execute:
    manifest = render_reference(7, mode=f'search_{mode}')
    print({'search': search, 'render': manifest})

# %% [markdown]
# ### Figure 8
# Expand the selected search configuration and render the figure.

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(8, mode=mode, execute=execute)
if execute:
    manifest = render_reference(8, mode=f'search_{mode}')
    print({'search': search, 'render': manifest})

# %% [markdown]
# ## Table 4 and Table 6
#
# The tables are generated from the experiment implementation labels `FeatFree-P`, `FeatFree-Kprop`, and `FeatFree-HOA`.

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.tables import render_table
mode = os.environ.get("AEC_MODE", "scaled")
execute = os.environ.get("AEC_EXECUTE", "0") == "1"
run_search_for_figure("table4", mode=mode, execute=execute)
if execute:
    render_table("table4", mode=f"search_{mode}")

# %%
from scripts.aec.search_runner import run_search_for_figure
from scripts.aec.tables import render_table
mode = os.environ.get("AEC_MODE", "scaled")
execute = os.environ.get("AEC_EXECUTE", "0") == "1"
run_search_for_figure("table6", mode=mode, execute=execute)
if execute:
    render_table("table6", mode=f"search_{mode}")
