# %% [markdown]
# # Notebook 3 — Search and Reproduce
#
# This notebook preserves the full AEC search path. It defaults to the claim-coverage scaled mode; use `AEC_MODE=full` with suitable compute for the complete configuration expansion.

# %% [markdown]
# ## Setup
#
# This cell checks the environment and creates portable output directories.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path.cwd().resolve()
while REPO_ROOT != REPO_ROOT.parent and not (REPO_ROOT / 'aec').is_dir():
    REPO_ROOT = REPO_ROOT.parent
sys.path.insert(0, str(REPO_ROOT))
from aec.environment import check_environment
from aec.paths import ensure_runtime_dirs
ensure_runtime_dirs()
ENV = check_environment(require_gpu=False)
print('Repository:', REPO_ROOT)
# Out:
# {'python': '3.10.20', 'executable': '/home/hzw/miniconda3/envs/HZWDP/bin/python', 'versions': {'torch': '2.5.1+cu121', 'torch-geometric': '2.7.0', 'numpy': '2.2.6', 'pandas': '2.3.3', 'matplotlib': '3.10.9', 'pyyaml': '6.0.3'}, 'cuda_available': True, 'cuda_count': 8, 'gpu_ids': [0], 'max_parallel_per_gpu': 1}
# Repository: /home/hzw/Rethinking_DP_GNN

# %% [markdown]
# ### Figure 1
# Expand the selected search configuration and render the figure.

# %%
from aec.search_runner import run_search_for_figure
from aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(1, mode=mode, execute=execute)
manifest = render_reference(1, mode=f'search_{mode}')
print({'search': search, 'render': manifest})
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure1_search_scaled/figure1.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure1_search_scaled/figure1.png
# {
#   "figure_id": 1,
#   "mode": "search_scaled",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure1_search_scaled",
#   "reference_table": "figure1_plot_data.csv"
# }
# {'search': {'figure_id': 1, 'mode': 'scaled', 'configs_total': 25, 'configs_selected': 6, 'runs': [{'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/LPGNN.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/LPGNN.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/Non-private.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/Non-private.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure1/scaled'], 'dry_run': True}]}, 'render': {'figure_id': 1, 'mode': 'search_scaled', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure1_search_scaled', 'reference_table': 'figure1_plot_data.csv'}}

# %% [markdown]
# ### Figure 2
# Expand the selected search configuration and render the figure.

# %%
from aec.search_runner import run_search_for_figure
from aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(2, mode=mode, execute=execute)
manifest = render_reference(2, mode=f'search_{mode}')
print({'search': search, 'render': manifest})
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure2_search_scaled/cora_alpha_epsilon_m_panels.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure2_search_scaled/cora_alpha_epsilon_m_panels.png
# {
#   "figure_id": 2,
#   "mode": "search_scaled",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure2_search_scaled",
#   "reference_table": null
# }
# {'search': {'figure_id': 2, 'mode': 'analytic', 'configs': 0}, 'render': {'figure_id': 2, 'mode': 'search_scaled', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure2_search_scaled', 'reference_table': None}}

# %% [markdown]
# ### Figure 3
# Expand the selected search configuration and render the figure.

# %%
from aec.search_runner import run_search_for_figure
from aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(3, mode=mode, execute=execute)
manifest = render_reference(3, mode=f'search_{mode}')
print({'search': search, 'render': manifest})
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure3_search_scaled/figure4_final_ldp_sim_panels.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure3_search_scaled/figure4_final_ldp_sim_panels.png
# {
#   "figure_id": 3,
#   "mode": "search_scaled",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure3_search_scaled",
#   "reference_table": "figure3_plot_data.csv"
# }
# {'search': {'figure_id': 3, 'mode': 'scaled', 'configs_total': 2, 'configs_selected': 1, 'runs': [{'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/LDP.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure3/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/LDP.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure3/scaled'], 'dry_run': True}]}, 'render': {'figure_id': 3, 'mode': 'search_scaled', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure3_search_scaled', 'reference_table': 'figure3_plot_data.csv'}}

# %% [markdown]
# ### Figure 4
# Expand the selected search configuration and render the figure.

# %%
from aec.search_runner import run_search_for_figure
from aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(4, mode=mode, execute=execute)
manifest = render_reference(4, mode=f'search_{mode}')
print({'search': search, 'render': manifest})
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure4_search_scaled/figure5_final_norm_scale_curves.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure4_search_scaled/figure5_final_norm_scale_curves.png
# {
#   "figure_id": 4,
#   "mode": "search_scaled",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure4_search_scaled",
#   "reference_table": "figure4_plot_data.csv"
# }
# {'search': {'figure_id': 4, 'mode': 'scaled', 'configs_total': 1, 'configs_selected': 1, 'runs': [{'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/figure4.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure4/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/figure4.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure4/scaled'], 'dry_run': True}]}, 'render': {'figure_id': 4, 'mode': 'search_scaled', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure4_search_scaled', 'reference_table': 'figure4_plot_data.csv'}}

# %% [markdown]
# ### Figure 5
# Expand the selected search configuration and render the figure.

# %%
from aec.search_runner import run_search_for_figure
from aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(5, mode=mode, execute=execute)
manifest = render_reference(5, mode=f'search_{mode}')
print({'search': search, 'render': manifest})
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure5_search_scaled/figure6_tao2_curves.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure5_search_scaled/figure6_tao2_curves.png
# {
#   "figure_id": 5,
#   "mode": "search_scaled",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure5_search_scaled",
#   "reference_table": "figure5_plot_data.csv"
# }
# {'search': {'figure_id': 5, 'mode': 'scaled', 'configs_total': 19, 'configs_selected': 4, 'runs': [{'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure5/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure5/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure5/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure5/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/LPGNN.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure5/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/LPGNN.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure5/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/Non-private.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure5/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/Non-private.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure5/scaled'], 'dry_run': True}]}, 'render': {'figure_id': 5, 'mode': 'search_scaled', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure5_search_scaled', 'reference_table': 'figure5_plot_data.csv'}}

# %% [markdown]
# ### Figure 6
# Expand the selected search configuration and render the figure.

# %%
from aec.search_runner import run_search_for_figure
from aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(6, mode=mode, execute=execute)
manifest = render_reference(6, mode=f'search_{mode}')
print({'search': search, 'render': manifest})
# Out:
# {
#   "figure_id": 6,
#   "mode": "search_scaled",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure6_search_scaled",
#   "reference_table": "figure6_plot_data.csv"
# }
# {'search': {'figure_id': 6, 'mode': 'scaled', 'configs_total': 19, 'configs_selected': 4, 'runs': [{'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure6/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure6/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure6/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/FeatFree.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure6/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/LPGNN.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure6/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/LPGNN.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure6/scaled'], 'dry_run': True}, {'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/Non-private.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure6/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/Non-private.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure6/scaled'], 'dry_run': True}]}, 'render': {'figure_id': 6, 'mode': 'search_scaled', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure6_search_scaled', 'reference_table': 'figure6_plot_data.csv'}}

# %% [markdown]
# ### Figure 7
# Expand the selected search configuration and render the figure.

# %%
from aec.search_runner import run_search_for_figure
from aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(7, mode=mode, execute=execute)
manifest = render_reference(7, mode=f'search_{mode}')
print({'search': search, 'render': manifest})
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure7_search_scaled/figure5_heter.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure7_search_scaled/figure5_heter.png
# {
#   "figure_id": 7,
#   "mode": "search_scaled",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure7_search_scaled",
#   "reference_table": "figure7_plot_data.csv"
# }
# {'search': {'figure_id': 7, 'mode': 'scaled', 'configs_total': 1, 'configs_selected': 1, 'runs': [{'mode': 'scaled', 'config': '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/figure7.yaml', 'output_root': '/home/hzw/Rethinking_DP_GNN/work/search/figure7/scaled', 'command': ['/home/hzw/miniconda3/envs/HZWDP/bin/python', '-u', '-m', 'hparams_search_scripts.run_mechanism_hparam_search', '--config', '/home/hzw/Rethinking_DP_GNN/work/scaled_configs/figure7.yaml', '--output_root_dir', '/home/hzw/Rethinking_DP_GNN/work/search/figure7/scaled'], 'dry_run': True}]}, 'render': {'figure_id': 7, 'mode': 'search_scaled', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure7_search_scaled', 'reference_table': 'figure7_plot_data.csv'}}

# %% [markdown]
# ### Figure 8
# Expand the selected search configuration and render the figure.

# %%
from aec.search_runner import run_search_for_figure
from aec.figures import render_reference
mode = os.environ.get('AEC_MODE', 'scaled')
execute = os.environ.get('AEC_EXECUTE', '0') == '1'
search = run_search_for_figure(8, mode=mode, execute=execute)
manifest = render_reference(8, mode=f'search_{mode}')
print({'search': search, 'render': manifest})
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure8_search_scaled/cora_pm_hds_alpha_lambda_epsilon.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure8_search_scaled/cora_pm_hds_alpha_lambda_epsilon.png
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure8_search_scaled/cora_pm_hds_alpha_lambda_epsilon_curve.csv
# Curve rows: 3211
# {
#   "figure_id": 8,
#   "mode": "search_scaled",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure8_search_scaled",
#   "reference_table": null
# }
# {'search': {'figure_id': 8, 'mode': 'analytic', 'configs': 0}, 'render': {'figure_id': 8, 'mode': 'search_scaled', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure8_search_scaled', 'reference_table': None}}

# %% [markdown]
# ## Table 4 and Table 6
#
# The tables are generated from the experiment implementation labels `FeatFree-P`, `FeatFree-Kprop`, and `FeatFree-HOA`.

# %%
from aec.search_runner import run_search_for_figure
from aec.tables import render_table
mode = os.environ.get("AEC_MODE", "scaled")
execute = os.environ.get("AEC_EXECUTE", "0") == "1"
run_search_for_figure("table4", mode=mode, execute=execute)
render_table("table4", mode=f"search_{mode}")
# Out:
# {
#   "table": "table4",
#   "mode": "search_scaled",
#   "rows": 12,
#   "seed_rows": 120
# }
# {'table': 'table4', 'mode': 'search_scaled', 'rows': 12, 'seed_rows': 120}

# %%
from aec.search_runner import run_search_for_figure
from aec.tables import render_table
mode = os.environ.get("AEC_MODE", "scaled")
execute = os.environ.get("AEC_EXECUTE", "0") == "1"
run_search_for_figure("table6", mode=mode, execute=execute)
render_table("table6", mode=f"search_{mode}")
# Out:
# {
#   "table": "table6",
#   "mode": "search_scaled",
#   "rows": 72,
#   "seed_rows": 720
# }
# {'table': 'table6', 'mode': 'search_scaled', 'rows': 72, 'seed_rows': 720}
