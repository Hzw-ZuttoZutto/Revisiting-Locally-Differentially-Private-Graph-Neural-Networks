# %% [markdown]
# # Notebook 1 — Direct Figure/Table Generation
#
# This notebook reads compact, inspectable reference data and generates all eight figures. It does not start training or require a GPU.

# %% [markdown]
# ## Setup
#
# This cell checks the environment and creates portable output directories.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path.cwd().resolve()
while REPO_ROOT != REPO_ROOT.parent and not (REPO_ROOT / 'scripts' / 'aec').is_dir():
    REPO_ROOT = REPO_ROOT.parent
sys.path.insert(0, str(REPO_ROOT))
from scripts.aec.environment import check_environment
from scripts.aec.paths import ensure_runtime_dirs
ensure_runtime_dirs()
ENV = check_environment(require_gpu=False)
print('Repository:', REPO_ROOT)
# Out:
# {'python': '3.10.21', 'executable': '/home/placitudo/APP/miniconda3/envs/rethinking-dp-gnn-aec/bin/python', 'versions': {'torch': '2.8.0', 'torch-geometric': '2.8.0', 'numpy': '2.2.6', 'pandas': '2.3.3', 'matplotlib': '3.10.9', 'pyyaml': '6.0.3'}, 'cuda_available': True, 'cuda_count': 4, 'gpu_ids': [0], 'max_parallel_per_gpu': 1}
# Repository: /home/placitudo/Revisiting-Locally-Differentially-Private-Graph-Neural-Networks

# %% [markdown]
# ### Figure 1
# Generate the paper figure from the compact reference data.

# %%
from scripts.aec.figures import render_reference
manifest = render_reference(1, mode='reference')
print(manifest)
# Out:
# Saved /tmp/aec-figure1-so0mzdzx/figure1.pdf
# Saved /tmp/aec-figure1-so0mzdzx/figure1.png
# {
#   "figure_id": 1,
#   "mode": "reference",
#   "displayed": true,
#   "source_table": "figure1_plot_data.csv"
# }
# {'figure_id': 1, 'mode': 'reference', 'displayed': True, 'source_table': 'figure1_plot_data.csv'}

# %% [markdown]
# ### Figure 2
# Generate the paper figure from the compact reference data.

# %%
from scripts.aec.figures import render_reference
manifest = render_reference(2, mode='reference')
print(manifest)

# %% [markdown]
# ### Figure 3
# Generate the paper figure from the compact reference data.

# %%
from scripts.aec.figures import render_reference
manifest = render_reference(3, mode='reference')
print(manifest)

# %% [markdown]
# ### Figure 4
# Generate the paper figure from the compact reference data.

# %%
from scripts.aec.figures import render_reference
manifest = render_reference(4, mode='reference')
print(manifest)

# %% [markdown]
# ### Figure 5
# Generate the paper figure from the compact reference data.

# %%
from scripts.aec.figures import render_reference
manifest = render_reference(5, mode='reference')
print(manifest)

# %% [markdown]
# ### Figure 6
# Generate the paper figure from the compact reference data.

# %%
from scripts.aec.figures import render_reference
manifest = render_reference(6, mode='reference')
print(manifest)

# %% [markdown]
# ### Figure 7
# Generate the paper figure from the compact reference data.

# %%
from scripts.aec.figures import render_reference
manifest = render_reference(7, mode='reference')
print(manifest)

# %% [markdown]
# ### Figure 8
# Generate the paper figure from the compact reference data.

# %%
from scripts.aec.figures import render_reference
manifest = render_reference(8, mode='reference')
print(manifest)

# %% [markdown]
# ## Table 4 and Table 6
#
# The tables are generated from the experiment implementation labels `FeatFree-P`, `FeatFree-Kprop`, and `FeatFree-HOA`.

# %%
from scripts.aec.tables import render_table
render_table("table4", mode="reference")

# %%
from scripts.aec.tables import render_table
render_table("table6", mode="reference")
