# %% [markdown]
# # Notebook 1 — Direct Figure Generation
#
# This notebook reads compact, inspectable reference data and generates all eight figures. It does not start training or require a GPU.

# %% [markdown]
# ## Setup
#
# This cell checks the environment and creates portable output directories.

# %%
from pathlib import Path
import os, sys
REPO_ROOT = Path.cwd().resolve()
while REPO_ROOT != REPO_ROOT.parent and not (REPO_ROOT / 'aec').is_dir():
    REPO_ROOT = REPO_ROOT.parent
sys.path.insert(0, str(REPO_ROOT))
from aec.environment import check_environment
from aec.paths import ensure_runtime_dirs
ensure_runtime_dirs()
ENV = check_environment(require_gpu=False)
print('Repository:', REPO_ROOT)
# Out:
# {'python': '3.10.20', 'executable': '/home/hzw/miniconda3/envs/HZWDP/bin/python', 'versions': {'torch': '2.5.1+cu121', 'torch-geometric': '2.7.0', 'numpy': '2.2.6', 'pandas': '2.3.3', 'matplotlib': '3.10.9', 'pyyaml': '6.0.3'}, 'cuda_available': True, 'cuda_count': 8, 'gpu_ids': [0], 'max_parallel_per_gpu': 1}
# Repository: /home/hzw/Rethinking_DP_GNN

# %% [markdown]
# ### Figure 1
# Generate the paper figure from the compact reference data.

# %%
from aec.figures import render_reference
manifest = render_reference(1, mode='reference')
print(manifest)
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure1/figure1.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure1/figure1.png
# {
#   "figure_id": 1,
#   "mode": "reference",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure1",
#   "reference_table": "figure1_plot_data.csv"
# }
# {'figure_id': 1, 'mode': 'reference', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure1', 'reference_table': 'figure1_plot_data.csv'}

# %% [markdown]
# ### Figure 2
# Generate the paper figure from the compact reference data.

# %%
from aec.figures import render_reference
manifest = render_reference(2, mode='reference')
print(manifest)
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure2/cora_alpha_epsilon_m_panels.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure2/cora_alpha_epsilon_m_panels.png
# {
#   "figure_id": 2,
#   "mode": "reference",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure2",
#   "reference_table": null
# }
# {'figure_id': 2, 'mode': 'reference', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure2', 'reference_table': None}

# %% [markdown]
# ### Figure 3
# Generate the paper figure from the compact reference data.

# %%
from aec.figures import render_reference
manifest = render_reference(3, mode='reference')
print(manifest)
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure3/figure4_final_ldp_sim_panels.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure3/figure4_final_ldp_sim_panels.png
# {
#   "figure_id": 3,
#   "mode": "reference",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure3",
#   "reference_table": "figure3_plot_data.csv"
# }
# {'figure_id': 3, 'mode': 'reference', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure3', 'reference_table': 'figure3_plot_data.csv'}

# %% [markdown]
# ### Figure 4
# Generate the paper figure from the compact reference data.

# %%
from aec.figures import render_reference
manifest = render_reference(4, mode='reference')
print(manifest)
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure4/figure5_final_norm_scale_curves.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure4/figure5_final_norm_scale_curves.png
# {
#   "figure_id": 4,
#   "mode": "reference",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure4",
#   "reference_table": "figure4_plot_data.csv"
# }
# {'figure_id': 4, 'mode': 'reference', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure4', 'reference_table': 'figure4_plot_data.csv'}

# %% [markdown]
# ### Figure 5
# Generate the paper figure from the compact reference data.

# %%
from aec.figures import render_reference
manifest = render_reference(5, mode='reference')
print(manifest)
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure5/figure6_tao2_curves.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure5/figure6_tao2_curves.png
# {
#   "figure_id": 5,
#   "mode": "reference",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure5",
#   "reference_table": "figure5_plot_data.csv"
# }
# {'figure_id': 5, 'mode': 'reference', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure5', 'reference_table': 'figure5_plot_data.csv'}

# %% [markdown]
# ### Figure 6
# Generate the paper figure from the compact reference data.

# %%
from aec.figures import render_reference
manifest = render_reference(6, mode='reference')
print(manifest)
# Out:
# {
#   "figure_id": 6,
#   "mode": "reference",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure6",
#   "reference_table": "figure6_plot_data.csv"
# }
# {'figure_id': 6, 'mode': 'reference', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure6', 'reference_table': 'figure6_plot_data.csv'}

# %% [markdown]
# ### Figure 7
# Generate the paper figure from the compact reference data.

# %%
from aec.figures import render_reference
manifest = render_reference(7, mode='reference')
print(manifest)
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure7/figure5_heter.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure7/figure5_heter.png
# {
#   "figure_id": 7,
#   "mode": "reference",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure7",
#   "reference_table": "figure7_plot_data.csv"
# }
# {'figure_id': 7, 'mode': 'reference', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure7', 'reference_table': 'figure7_plot_data.csv'}

# %% [markdown]
# ### Figure 8
# Generate the paper figure from the compact reference data.

# %%
from aec.figures import render_reference
manifest = render_reference(8, mode='reference')
print(manifest)
# Out:
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure8/cora_pm_hds_alpha_lambda_epsilon.pdf
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure8/cora_pm_hds_alpha_lambda_epsilon.png
# Saved /home/hzw/Rethinking_DP_GNN/outputs/figure8/cora_pm_hds_alpha_lambda_epsilon_curve.csv
# Curve rows: 3211
# {
#   "figure_id": 8,
#   "mode": "reference",
#   "output_dir": "/home/hzw/Rethinking_DP_GNN/outputs/figure8",
#   "reference_table": null
# }
# {'figure_id': 8, 'mode': 'reference', 'output_dir': '/home/hzw/Rethinking_DP_GNN/outputs/figure8', 'reference_table': None}

# %% [markdown]
# ## Table 4 and Table 6
#
# The tables are generated from the experiment implementation labels `FeatFree-P`, `FeatFree-Kprop`, and `FeatFree-HOA`.

# %%
from aec.tables import render_table
render_table("table4", mode="reference")
# Out:
# {
#   "table": "table4",
#   "mode": "reference",
#   "rows": 12,
#   "seed_rows": 120
# }
# {'table': 'table4', 'mode': 'reference', 'rows': 12, 'seed_rows': 120}

# %%
from aec.tables import render_table
render_table("table6", mode="reference")
# Out:
# {
#   "table": "table6",
#   "mode": "reference",
#   "rows": 72,
#   "seed_rows": 720
# }
# {'table': 'table6', 'mode': 'reference', 'rows': 72, 'seed_rows': 720}
